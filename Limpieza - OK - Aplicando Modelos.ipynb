# %%
import pandas as pd 
import numpy as np

train = pd.read_csv("TitanicTrain.csv")
test = pd.read_csv("TitanicTest.csv")
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
#mostrar columnas de train
train.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
#mostrar columnas de test
test.columns.values
# Out:
# array(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
#
train = pd.get_dummies(train, columns = ["Sex"], drop_first = True)
train.rename(columns = {'Sex_male':'Sexo'},inplace=True)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
#Sexo a 1 y 0 segun lo contenga tabla Test
test = pd.get_dummies(test, columns = ["Sex"], drop_first = True)
test.rename(columns = {'Sex_male':'Sexo'},inplace=True)
test
# Out:
#      PassengerId  Pclass                                          Name   Age  \
# 0            892       3                              Kelly, Mr. James  34.5
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2            894       2                     Myles, Mr. Thomas Francis  62.0
# 3            895       3                              Wirz, Mr. Albert  27.0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..           ...     ...                                           ...   ...
# 413         1305       3                            Spector, Mr. Woolf   NaN
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  39.0
# 415         1307       3                  Saether, Mr. Simon Sivertsen  38.5
# 416         1308       3                           Ware, Mr. Frederick   NaN
# 417         1309       3                      Peter, Master. Michael J   NaN
#
# ...

# %%
#Reemplazamos Q por un numero de la tabla Train
train.loc[train['Embarked'] == 'C', 'Embarked'] = 1
train.loc[train['Embarked'] == 'Q', 'Embarked'] = 2
train.loc[train['Embarked'] == 'S', 'Embarked'] = 3
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name   Age  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris  22.0      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                               Heikkinen, Miss. Laina  26.0      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                             Allen, Mr. William Henry  35.0      0      0
# ..                                                 ...   ...    ...    ...
# ...

# %%
#Reemplazamos Q por un numero de la tabla Test
test.loc[test['Embarked'] == 'C', 'Embarked'] = 1
test.loc[test['Embarked'] == 'Q', 'Embarked'] = 2
test.loc[test['Embarked'] == 'S', 'Embarked'] = 3
test
# Out:
#      PassengerId  Pclass                                          Name   Age  \
# 0            892       3                              Kelly, Mr. James  34.5
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)  47.0
# 2            894       2                     Myles, Mr. Thomas Francis  62.0
# 3            895       3                              Wirz, Mr. Albert  27.0
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..           ...     ...                                           ...   ...
# 413         1305       3                            Spector, Mr. Woolf   NaN
# 414         1306       1                  Oliva y Ocana, Dona. Fermina  39.0
# 415         1307       3                  Saether, Mr. Simon Sivertsen  38.5
# 416         1308       3                           Ware, Mr. Frederick   NaN
# 417         1309       3                      Peter, Master. Michael J   NaN
#
# ...

# %%
#Sacar promedio de los años 
#promTest = test['Age'].mean()
test['Age'].mean()
# Out:
# 30.272590361445783

# %%
promTrain = train['Age'].mean()

# %%
#remplazar NaN por el promedio de edad 
Age = train["Age"].fillna(promTrain, inplace = True)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.000000      1
# 2                               Heikkinen, Miss. Laina  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.000000      1
# 4                             Allen, Mr. William Henry  35.000000      0
# ..                                                 ...        ...    ...
# ...

# %%
Age = test["Age"].fillna(promTest , inplace = True)
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#           Age  SibSp  Parch              Ticket      Fare Cabin Embarked  Sexo
# ...

# %%
#Eliminar columna Cabin
test.drop(['Cabin','Name','Ticket'], axis='columns', inplace=True)
test
# Out:
#      PassengerId  Pclass       Age  SibSp  Parch      Fare Embarked  Sexo
# 0            892       3  34.50000      0      0    7.8292        2     1
# 1            893       3  47.00000      1      0    7.0000        3     0
# 2            894       2  62.00000      0      0    9.6875        2     1
# 3            895       3  27.00000      0      0    8.6625        3     1
# 4            896       3  22.00000      1      1   12.2875        3     0
# ..           ...     ...       ...    ...    ...       ...      ...   ...
# 413         1305       3  30.27259      0      0    8.0500        3     1
# 414         1306       1  39.00000      0      0  108.9000        1     0
# 415         1307       3  38.50000      0      0    7.2500        3     1
# 416         1308       3  30.27259      0      0    8.0500        3     1
# 417         1309       3  30.27259      1      1   22.3583        1     1
#
# [418 rows x 8 columns]

# %%
#Eliminar columna Cabin
train.drop(['Cabin','Name','Ticket'], axis='columns', inplace=True)
train
# Out:
#      PassengerId  Survived  Pclass        Age  SibSp  Parch     Fare Embarked  \
# 0              1         0       3  22.000000      1      0   7.2500        3
# 1              2         1       1  38.000000      1      0  71.2833        1
# 2              3         1       3  26.000000      0      0   7.9250        3
# 3              4         1       1  35.000000      1      0  53.1000        3
# 4              5         0       3  35.000000      0      0   8.0500        3
# ..           ...       ...     ...        ...    ...    ...      ...      ...
# 886          887         0       2  27.000000      0      0  13.0000        3
# 887          888         1       1  19.000000      0      0  30.0000        3
# 888          889         0       3  29.699118      1      2  23.4500        3
# 889          890         1       1  26.000000      0      0  30.0000        1
# 890          891         0       3  32.000000      0      0   7.7500        2
#
#      Sexo
# 0       1
# ...

# %%
#Realizamos una categorizacion de las edades, realizando un arreglo que nos dara los rangos de las edades, y los cuales
#los reemplazaron con los datos del arreglo llamaod 'datos'. Este hara mas simple la lectura para los modelos aplicar
rangos = [0, 8, 15, 18, 25, 40, 60, 100]
datos = ['1', '2', '3', '4', '5', '6', '7']
train.Age = pd.cut(train.Age,rangos,labels=datos)

# %%
train
# Out:
#      PassengerId  Survived  Pclass Age  SibSp  Parch     Fare Embarked  Sexo
# 0              1         0       3   4      1      0   7.2500        3     1
# 1              2         1       1   5      1      0  71.2833        1     0
# 2              3         1       3   5      0      0   7.9250        3     0
# 3              4         1       1   5      1      0  53.1000        3     0
# 4              5         0       3   5      0      0   8.0500        3     1
# ..           ...       ...     ...  ..    ...    ...      ...      ...   ...
# 886          887         0       2   5      0      0  13.0000        3     1
# 887          888         1       1   4      0      0  30.0000        3     0
# 888          889         0       3   5      1      2  23.4500        3     0
# 889          890         1       1   5      0      0  30.0000        1     1
# 890          891         0       3   5      0      0   7.7500        2     1
#
# [891 rows x 9 columns]

# %%
rangos = [0, 8, 15, 18, 25, 40, 60, 100]
datos = ['1', '2', '3', '4', '5', '6', '7']
test.Age = pd.cut(test.Age,rangos,labels=datos)

# %%
test
# Out:
#      PassengerId  Pclass Age  SibSp  Parch      Fare Embarked  Sexo
# 0            892       3   5      0      0    7.8292        2     1
# 1            893       3   6      1      0    7.0000        3     0
# 2            894       2   7      0      0    9.6875        2     1
# 3            895       3   5      0      0    8.6625        3     1
# 4            896       3   4      1      1   12.2875        3     0
# ..           ...     ...  ..    ...    ...       ...      ...   ...
# 413         1305       3   5      0      0    8.0500        3     1
# 414         1306       1   5      0      0  108.9000        1     0
# 415         1307       3   5      0      0    7.2500        3     1
# 416         1308       3   5      0      0    8.0500        3     1
# 417         1309       3   5      1      1   22.3583        1     1
#
# [418 rows x 8 columns]

# %%
#Revisamos que no hayan datos nulos, que nos entorpescan los modelos
pd.isnull(train).sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# Sexo           0
# dtype: int64

# %%
pd.isnull(test).sum()
# Out:
# PassengerId    0
# Pclass         0
# Age            0
# SibSp          0
# Parch          0
# Fare           1
# Embarked       0
# Sexo           0
# dtype: int64

# %%
#Como anteriormente existieron datos nulos, lo borramos.
train.dropna(axis=0, how='any', inplace=True)
train
# Out:
#      PassengerId  Survived  Pclass Age  SibSp  Parch     Fare Embarked  Sexo
# 0              1         0       3   4      1      0   7.2500        3     1
# 1              2         1       1   5      1      0  71.2833        1     0
# 2              3         1       3   5      0      0   7.9250        3     0
# 3              4         1       1   5      1      0  53.1000        3     0
# 4              5         0       3   5      0      0   8.0500        3     1
# ..           ...       ...     ...  ..    ...    ...      ...      ...   ...
# 886          887         0       2   5      0      0  13.0000        3     1
# 887          888         1       1   4      0      0  30.0000        3     0
# 888          889         0       3   5      1      2  23.4500        3     0
# 889          890         1       1   5      0      0  30.0000        1     1
# 890          891         0       3   5      0      0   7.7500        2     1
#
# [889 rows x 9 columns]

# %%
test.dropna(axis=0, how='any', inplace=True)
test
# Out:
#      PassengerId  Pclass Age  SibSp  Parch      Fare Embarked  Sexo
# 0            892       3   5      0      0    7.8292        2     1
# 1            893       3   6      1      0    7.0000        3     0
# 2            894       2   7      0      0    9.6875        2     1
# 3            895       3   5      0      0    8.6625        3     1
# 4            896       3   4      1      1   12.2875        3     0
# ..           ...     ...  ..    ...    ...       ...      ...   ...
# 413         1305       3   5      0      0    8.0500        3     1
# 414         1306       1   5      0      0  108.9000        1     0
# 415         1307       3   5      0      0    7.2500        3     1
# 416         1308       3   5      0      0    8.0500        3     1
# 417         1309       3   5      1      1   22.3583        1     1
#
# [417 rows x 8 columns]

# %% [markdown]
# # Aplicacion Modelos

# %%
# Creamos el arreglo X sin la columna supervivientes, ya que seran nuestro datos de entrada
X = np.array(train.drop(['Survived'], 1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ff492128b8bb> in <module>()
#       1 # Creamos el arreglo X sin la columna supervivientes, ya que seran nuestro datos de entrada
# ----> 2 X = np.array(train.drop(['Survived'], 1))
#
# NameError: name 'np' is not defined

# %%
# Creamos el arreglo Y solo con columna supervivientes, ya que seran nuestro datos de salida
y = np.array(train['Survived'])

# %% [markdown]
# A continuacion realizamos el split test, para tener los datos de entrenamiento y prueba. Recordemos que como test_size usamos
# 0.2 ya que significa que usamos solo en 20% de los datos para las pruebas. Pero esto puede variar segun nuestra cantidad de
# datos que tengamos.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# #  Regresion Logistica

# %% [markdown]
# Ahora como primer modelo, la regresion logistica, pero porque no la lineal, bueno la lineal solo nos sirve si tenemos una variable
# Continua, mientra que el de regresion logistica nos sirve cuando nuestro datos de interes es dicotomico, osea toma los valores
# si/no o 1/0 como la columna ['Survived']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier


relog = LogisticRegression()
#Entrenamos el modelo con el comando FIT
relog.fit(X_train, y_train)
# Realizamos las predicciones para probar nuestro modelo con el comando predict
Y_pred_relog = relog.predict(X_test)
print(f"Precisión de la predicción %.2f" %(relog.score(X_train, y_train)*100),"%")
# Out:
# Precisión de la predicción 79.61 %
# C:\Users\Jonathan Santander\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# Como vemos el modelo nos dio una prediccion del 80.03% que no esta mal para el primer modelo. Ahora veremos que sucederia con
# los datos normalizados

# %% [markdown]
# ## Normalizacion

# %%
# Normalizacion
from sklearn.preprocessing import MinMaxScaler

#Realizamos un escalado de los datos de entrenamiento
norma = MinMaxScaler().fit(X_train)

# Realizamos la normalizacion de los datos train y test
X_train_norm = norma.transform(X_train)

X_test_norm = norma.transform(X_test)

#Ahora que tenemos los datos normalzados, usaremos denuevo el modelo anterior y veremos como nos va.

# %%
# Regresion logistica pero con los datos normalizados

relog = LogisticRegression()
#Entrenamos el modelo con el comando FIT
relog.fit(X_train_norm, y_train)
# Realizamos las predicciones para probar nuestro modelo con el comando predict
Y_pred_relog = relog.predict(X_test_norm)
print(f"Precisión de la predicción %.2f" %(relog.score(X_train_norm, y_train)*100),"%")
# Out:
# Precisión de la predicción 80.59 %

# %% [markdown]
# ## Estandarizacion

# %%
# Estandarizacion
from sklearn.preprocessing import StandardScaler
scala = StandardScaler().fit(X_train)
X_train_stand = scala.transform(X_train)
X_test_stand = scala.transform(X_test)

# %%
# Regresion logistica pero con los datos estandarizados

relog = LogisticRegression()
#Entrenamos el modelo con el comando FIT
relog.fit(X_train_stand, y_train)
# Realizamos las predicciones para probar nuestro modelo con el comando predict
Y_pred_relog = relog.predict(X_test_stand)
print(f"Precisión de la predicción %.2f" %(relog.score(X_train_stand, y_train)*100),"%")
# Como podemos ver con los datos estandarizados, tenemos una mejora pero no muy significante ya que fue solo un 0.84%.
# Out:
# Precisión de la predicción 80.87 %

# %% [markdown]
# # Modelo Support Vector Machine

# %% [markdown]
# Ahora aplicaremos el Modelo Support Vector Machine

# %%
from sklearn.svm import SVC
# Modelo Support Vector Machine
# Aqui llamamos a la funcion SVC y la guardamos en una variable llamada svc.
svc = SVC()
# Aqui entrenamos al modelos con la funcion fit.
svc.fit(X_train, y_train)
# Realizamos las predicciones para probar nuestro modelo con el comando predict
Y_pred_svc = svc.predict(X_test)
print(f"Precisión de la predicción %.2f" %(svc.score(X_train, y_train)*100),"%")
# Out:
# Precisión de la predicción 64.84 %

# %%
# Modelo Support Vector Machine / Datos Normalizados
svc = SVC()
svc.fit(X_train_norm, y_train)
Y_pred = svc.predict(X_test_norm)
print(f"Precisión de la predicción %.2f" %(svc.score(X_train_norm, y_train)*100),"%")
# Out:
# Precisión de la predicción 83.12 %

# %%
# Modelo Support Vector Machine / Datos Estandarizados
svc = SVC()
svc.fit(X_train_stand, y_train)
Y_pred = svc.predict(X_test_stand)
print(f"Precisión de la predicción %.2f" %(svc.score(X_train_stand, y_train)*100),"%")
# Out:
# Precisión de la predicción 84.53 %

# %% [markdown]
# Usando el modelo Support Vector Machine, tenemos un porcentaje de prediccion del 97.89% con los datos sin modificar. Pero no tenemos mejora si normalizamos o estandarizamos los datos con una diferencia del 13.17% en promedio. Hasta ahora este modelo iria por buen camino. Ahora pasaremos al Random Forest Classifier

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
RndF = RandomForestClassifier()
# Aqui entrenamos al modelos con la funcion fit.
RndF.fit(X_train,y_train)
# Realizamos las predicciones para probar nuestro modelo con el comando predict
Y_pred_rfc = RndF.predict(X_train)
print(f"Precisión de la predicción %.2f" %(RndF.score(X_train, y_train)*100),"%")
# Out:
# Precisión de la predicción 100.00 %

# %%
# Random Forest Classifier / Datos Normalizados
RndF = RandomForestClassifier()
RndF.fit(X_train_norm,y_train)
Y_pred = RndF.predict(X_train_norm)
print(f"Precisión de la predicción %.2f" %(RndF.score(X_train_norm, y_train)*100),"%")
# Out:
# Precisión de la predicción 100.00 %

# %%
# Random Forest Classifier / Datos Estandarizados
RndF = RandomForestClassifier()
RndF.fit(X_train_stand,y_train)
Y_pred = RndF.predict(X_train_stand)
print(f"Precisión de la predicción %.2f" %(RndF.score(X_train_stand, y_train)*100),"%")
# Out:
# Precisión de la predicción 100.00 %

# %% [markdown]
# Como podemos ver los datos sin normalizar no dieron una mejora del 0.28% en comparacion a los datos normalizados. Pero por otro lado tampoco nos dio una mejora significante con el modelo de Vector Machine, ya que tuvimos una mejora del 0.28%. Pero en comparacion con la regresion logistica tuvimos una mejora del 18.14%. Por lo cual, podriamos decir que hasta ahora es nuestro mejor modelo hasta ahora. Ahora usaremos el modelo de los vecinos mas cercanos o k-Nearest Neighbor.

# %% [markdown]
# #  k-Nearest Neighbor.

# %% [markdown]
# Antes de comenzar a utilizar el modelo, k-Nearest Neighbor debemos encontrar el numero que nos permitira dar con la mejor precision.

# %%
from sklearn import metrics
# Para descubrir el k=n que utilizaremos haremos un loop con los numero del 0 al 25. Y Ver cual de estos nos daria el mejor
# resultado.
k_range = range(1, 26)
# Creamos un array llamado datos que nos guardara los datos obtenidos por el modelo para despues graficarlos.
datos = []

# Y ahora usamos el modelo en un for.
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    #Con este comando podemos sacar el porcentaje de exito del modelo con cada k.
    datos.append(metrics.accuracy_score(y_test, y_pred))

print(datos)
# Out:
# [0.5786516853932584, 0.5955056179775281, 0.5842696629213483, 0.6348314606741573, 0.6067415730337079, 0.6573033707865169, 0.6292134831460674, 0.651685393258427, 0.6123595505617978, 0.651685393258427, 0.6573033707865169, 0.6741573033707865, 0.6741573033707865, 0.651685393258427, 0.6460674157303371, 0.6573033707865169, 0.6629213483146067, 0.6741573033707865, 0.6629213483146067, 0.6797752808988764, 0.6741573033707865, 0.6685393258426966, 0.6853932584269663, 0.6797752808988764, 0.6910112359550562]

# %% [markdown]
# Como podemos ver tenemos hartos datos, pero vistos de esta forma no queda muy claro, por lo cual pasaremos a graficarlos.

# %%
# importamos el pyplot
import matplotlib.pyplot as plt

# %matplotlib inline

# Realizamos la relacion entre K y la tasa de exito
plt.plot(k_range, datos)
plt.xlabel('Valores de K por KNN')
plt.ylabel('Tasa de exito')
# Out:
# Text(0, 0.5, 'Tasa de exito')

# %% [markdown]
# Como podemos ver un valor cerca de 20 nos daria una buena tasa de exito, para corroborar la usaremos en el siguiente codigo.

# %%
# Reemplazamos con 19, ya que este es el numero que mayor % nos dio.
n_neighbors = 19
 
knn = KNeighborsClassifier(n_neighbors)
knn.fit(X_train, y_train)
print('Precision del K-NN: {:.2f}'
     .format(knn.score(X_train, y_train)))
# Out:
# Precision del K-NN: 0.69

# %% [markdown]
# Y como podemos ver tenemos una precision del 69%, con K=19 pero el resultado no es muy esperanzador comparado con los otros
# modelos. Ahora realizaremos lo mismo que realizamos anteriormente pero con los datos normalizados y estandarizados.

# %%
from sklearn import metrics
# Para descubrir el k=n que utilizaremos haremos un loop con los numero del 0 al 25. Y Ver cual de estos nos daria el mejor
# resultado.
k_range = range(1, 26)
# Creamos un array llamado datos que nos guardara los datos obtenidos por el modelo para despues graficarlos.
datos = []

# Y ahora usamos el modelo en un for.
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    #Reemplazamo el X_train con X_train_norm que es nuestra variable con los datos normalizados.
    knn.fit(X_train_norm, y_train)
    y_pred = knn.predict(X_test_norm)
    #Con este comando podemos sacar el porcentaje de exito del modelo con cada k.
    datos.append(metrics.accuracy_score(y_test, y_pred))

print(datos)
# Out:
# [0.7191011235955056, 0.7696629213483146, 0.7808988764044944, 0.7865168539325843, 0.7921348314606742, 0.7921348314606742, 0.7696629213483146, 0.7865168539325843, 0.7808988764044944, 0.7752808988764045, 0.7584269662921348, 0.7808988764044944, 0.7752808988764045, 0.797752808988764, 0.7808988764044944, 0.797752808988764, 0.7921348314606742, 0.7921348314606742, 0.797752808988764, 0.797752808988764, 0.7921348314606742, 0.797752808988764, 0.7752808988764045, 0.7865168539325843, 0.7528089887640449]

# %%
# importamos el pyplot
import matplotlib.pyplot as plt

# %matplotlib inline

# Realizamos la relacion entre K y la tasa de exito
plt.plot(k_range, datos)
plt.xlabel('Valores de K por KNN')
plt.ylabel('Tasa de exito')
# Out:
# Text(0, 0.5, 'Tasa de exito')

# %% [markdown]
# Ahora con los datos normalizados podemos ver que tendriamos una mejora sobre el 80% con K=20. Para corroborar realizaremos el modelos con K=20

# %%
# Reemplazamos con 20, ya que este es el numero que mayor % nos dio.
n_neighbors = 20
 
knn = KNeighborsClassifier(n_neighbors)
#Reemplazamos con los datos normalizados
knn.fit(X_train_norm, y_train)
print('Precision del K-NN: {:.2f}'
     .format(knn.score(X_train_norm, y_train)))
# Out:
# Precision del K-NN: 0.82

# %% [markdown]
# Y como podemos ver ahora tenemos una precision del 82%, con K=20 pero aunque tenemos una mejora del 13% aun asi no supera al modelo de Random Forest Classifier que tiene una exactitud de 98%.
# Ahora para continuar realizaremos, los mismo pero con los datos estandarizados para ver si existe una diferencia.

# %%
from sklearn import metrics
# Para descubrir el k=n que utilizaremos haremos un loop con los numero del 0 al 25. Y Ver cual de estos nos daria el mejor
# resultado.
k_range = range(1, 26)
# Creamos un array llamado datos que nos guardara los datos obtenidos por el modelo para despues graficarlos.
datos = []

# Y ahora usamos el modelo en un for.
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    #Reemplazamos la variable con los datos estandarizados
    knn.fit(X_train_stand, y_train)
    y_pred = knn.predict(X_test_stand)
    #Con este comando podemos sacar el porcentaje de exito del modelo con cada k.
    datos.append(metrics.accuracy_score(y_test, y_pred))

print(datos)
# Out:
# [0.7303370786516854, 0.7752808988764045, 0.7696629213483146, 0.7921348314606742, 0.7921348314606742, 0.797752808988764, 0.8033707865168539, 0.7921348314606742, 0.7752808988764045, 0.7808988764044944, 0.7696629213483146, 0.7752808988764045, 0.7584269662921348, 0.7808988764044944, 0.7528089887640449, 0.7808988764044944, 0.7640449438202247, 0.7808988764044944, 0.7584269662921348, 0.7752808988764045, 0.7640449438202247, 0.7696629213483146, 0.7584269662921348, 0.7640449438202247, 0.7640449438202247]

# %%
# importamos el pyplot
import matplotlib.pyplot as plt

# %matplotlib inline

# Realizamos la relacion entre K y la tasa de exito
plt.plot(k_range, datos)
plt.xlabel('Valores de K por KNN')
plt.ylabel('Tasa de exito')
# Out:
# Text(0, 0.5, 'Tasa de exito')

# %% [markdown]
# Como podemos ver, no se aprecia una mejora con los datos estandarizados, podemos que con k=10 los datos apenas superan el 80%

# %%
# Reemplazamos con 10, ya que este es el numero que mayor % nos dio.
n_neighbors = 10
 
knn = KNeighborsClassifier(n_neighbors)
#Reemplazamos con los datos normalizados
knn.fit(X_train_norm, y_train)
print('Precision del K-NN: {:.2f}'
     .format(knn.score(X_train_norm, y_train)))
# Out:
# Precision del K-NN: 0.84

# %% [markdown]
# Y Como podemos ver tenemos un 84% de exactitud comparado con los datos normalizados. Osea tenemos una mejora del 2%.
# Ahora para encontrar el mejor modelos aplicar usaremos el metodo de la Curva de AUC

# %% [markdown]
# # Curva AUC - ROC

# %% [markdown]
# Midiendo curva para Random Forest (En este caso es mejor y más eficiente con los datos estandarizados)

# %%
#Se mide la eficiencia para el modelo de RANDOM FOREST.
from sklearn.metrics import roc_auc_score
#Se obtienen las probabilidades de la prediccion.
prob_RndF = RndF.predict_proba(X_test)
prob_RndF = prob_RndF[:, 1]  
auc = roc_auc_score(y_test, prob_RndF)  
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.42

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, prob_RndF) 
plt.plot(fpr, tpr, color='red', label='ROC')
plt.plot([0, 1], [0, 1], color='blue', linestyle='-')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Caracteristica Operativa Receptor (Curva ROC)')
plt.legend()
plt.show()

# %% [markdown]
# Se mide curva para datos normalizados

# %%
#Se mide la eficiencia para el modelo de RANDOM FOREST normalizado.
from sklearn.metrics import roc_auc_score
prob_RndF = RndF.predict_proba(X_test_norm)
prob_RndF = prob_RndF[:, 1]  
auc = roc_auc_score(y_test, prob_RndF)  
print('AUC: %.2f' % auc)
# Out:
# AUC: 0.52

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, prob_KNN) 
plt.plot(fpr, tpr, color='red', label='ROC')
plt.plot([0, 1], [0, 1], color='blue', linestyle='-')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Caracteristica Operativa Receptor (Curva ROC)')
plt.legend()
plt.show()

# %% [markdown]
# Se mide la curva para datos estandarizados.

# %%
from sklearn.metrics import roc_auc_score
prob_RndF = RndF.predict_proba(X_test_norm)
prob_RndF = prob_RndF[:, 1]  
auc = roc_auc_score(y_test, prob_RndF)  
print('AUC: %.2f' % auc)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-111c3801ebe6> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 confusion_matrix(y_test, Y_pred_rfc)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      78     y_pred : array or indicator matrix
#      79     """
# ---> 80     check_consistent_length(y_true, y_pred)
#      81     type_true = type_of_target(y_true)
#      82     type_pred = type_of_target(y_pred)
#
# ...
